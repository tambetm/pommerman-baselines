# %%
import numpy as np
from keras.models import Model, load_model
from keras.layers import Input, Conv2D, Flatten, Dense
from keras.callbacks import ModelCheckpoint, EarlyStopping
import tensorflow as tf
import keras.backend as K
from sklearn.metrics import explained_variance_score, accuracy_score
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /home/tambet/.conda/envs/pommer/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# make sure TF does not allocate all memory
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
K.set_session(tf.Session(config=config))

# %%
data = np.load('single_600K_disc0.9.npz')
x_train = data['observations']
p_train = data['actions']
v_train = data['rewards']
x_train.shape, p_train.shape, v_train.shape
# Out:
# ((600000, 11, 11, 18), (600000,), (600000,))

# %%
data = np.load('valid_single_80K_disc0.9.npz')
x_test = data['observations']
p_test = data['actions']
v_test = data['rewards']
x_test.shape, p_test.shape, v_test.shape
# Out:
# ((80000, 11, 11, 18), (80000,), (80000,))

# %%
c = x = Input(shape=(11,11,18))
c = Conv2D(filters=32, kernel_size=3, strides=1, activation="relu", padding="same")(c)
c = Conv2D(filters=32, kernel_size=3, strides=1, activation="relu", padding="same")(c)
c = Conv2D(filters=32, kernel_size=3, strides=1, activation="relu", padding="same")(c)
h = Flatten()(c)
#h = Dense(128, activation='relu')(h)
p = Dense(6, activation="softmax", name='p')(h)
#h = Dense(128, activation='relu')(h)
v = Dense(1, activation="tanh", name='v')(h)
model = Model(x, [p, v])
model.summary()
model.compile(optimizer='adam', loss=['sparse_categorical_crossentropy', 'mse'], loss_weights=[0, 1], metrics={'p': 'accuracy'})
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 11, 11, 18)   0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 11, 11, 32)   5216        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 11, 11, 32)   9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 11, 11, 32)   9248        conv2d_2[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 3872)         0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# p (Dense)                       (None, 6)            23238       flatten_1[0][0]
# __________________________________________________________________________________________________
# v (Dense)                       (None, 1)            3873        flatten_1[0][0]
# ==================================================================================================
# Total params: 50,823
# Trainable params: 50,823
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
callbacks = [
    ModelCheckpoint('conv32_single_value_disc0.9_best.h5', monitor='val_v_loss', verbose=1, save_best_only=True, mode='auto'),
    EarlyStopping(monitor='val_v_loss', min_delta=0.001, patience=5, verbose=1, mode='auto')
]

# %%
history = model.fit(x_train, [p_train, v_train], batch_size=512, epochs=100, validation_data=(x_test, [p_test, v_test]), callbacks=callbacks)
# Out:
# Train on 600000 samples, validate on 80000 samples
# Epoch 1/100
# 600000/600000 [==============================] - 37s 62us/step - loss: 0.0309 - p_loss: 1.7956 - v_loss: 0.0309 - p_acc: 0.1587 - val_loss: 0.0269 - val_p_loss: 1.7920 - val_v_loss: 0.0269 - val_p_acc: 0.1584
#
# Epoch 00001: val_v_loss improved from inf to 0.02686, saving model to conv32_single_value_disc0.9_best.h5
# Epoch 2/100
# 600000/600000 [==============================] - 35s 58us/step - loss: 0.0245 - p_loss: 1.7923 - v_loss: 0.0245 - p_acc: 0.1549 - val_loss: 0.0252 - val_p_loss: 1.7927 - val_v_loss: 0.0252 - val_p_acc: 0.1512
#
# Epoch 00002: val_v_loss improved from 0.02686 to 0.02518, saving model to conv32_single_value_disc0.9_best.h5
# Epoch 3/100
# 600000/600000 [==============================] - 35s 58us/step - loss: 0.0231 - p_loss: 1.7915 - v_loss: 0.0231 - p_acc: 0.1627 - val_loss: 0.0237 - val_p_loss: 1.7908 - val_v_loss: 0.0237 - val_p_acc: 0.1716
#
# Epoch 00003: val_v_loss improved from 0.02518 to 0.02372, saving model to conv32_single_value_disc0.9_best.h5
# Epoch 4/100
# 600000/600000 [==============================] - 35s 58us/step - loss: 0.0223 - p_loss: 1.7911 - v_loss: 0.0223 - p_acc: 0.1643 - val_loss: 0.0229 - val_p_loss: 1.7913 - val_v_loss: 0.0229 - val_p_acc: 0.1576
#
# Epoch 00004: val_v_loss improved from 0.02372 to 0.02286, saving model to conv32_single_value_disc0.9_best.h5
# Epoch 5/100
# 600000/600000 [==============================] - 35s 58us/step - loss: 0.0217 - p_loss: 1.7915 - v_loss: 0.0217 - p_acc: 0.1500 - val_loss: 0.0228 - val_p_loss: 1.7914 - val_v_loss: 0.0228 - val_p_acc: 0.1547
#
# Epoch 00005: val_v_loss improved from 0.02286 to 0.02277, saving model to conv32_single_value_disc0.9_best.h5
# Epoch 6/100
# 600000/600000 [==============================] - 35s 58us/step - loss: 0.0213 - p_loss: 1.7917 - v_loss: 0.0213 - p_acc: 0.1485 - val_loss: 0.0221 - val_p_loss: 1.7920 - val_v_loss: 0.0221 - val_p_acc: 0.1381
#
# Epoch 00006: val_v_loss improved from 0.02277 to 0.02205, saving model to conv32_single_value_disc0.9_best.h5
# Epoch 7/100
# 600000/600000 [==============================] - 35s 58us/step - loss: 0.0209 - p_loss: 1.7917 - v_loss: 0.0209 - p_acc: 0.1502 - val_loss: 0.0220 - val_p_loss: 1.7913 - val_v_loss: 0.0220 - val_p_acc: 0.1515
#
# Epoch 00007: val_v_loss improved from 0.02205 to 0.02203, saving model to conv32_single_value_disc0.9_best.h5
# Epoch 8/100
# 600000/600000 [==============================] - 35s 58us/step - loss: 0.0205 - p_loss: 1.7914 - v_loss: 0.0205 - p_acc: 0.1520 - val_loss: 0.0228 - val_p_loss: 1.7916 - val_v_loss: 0.0228 - val_p_acc: 0.1423
#
# Epoch 00008: val_v_loss did not improve from 0.02203
# Epoch 9/100
# 600000/600000 [==============================] - 35s 58us/step - loss: 0.0202 - p_loss: 1.7918 - v_loss: 0.0202 - p_acc: 0.1459 - val_loss: 0.0224 - val_p_loss: 1.7922 - val_v_loss: 0.0224 - val_p_acc: 0.1406
#
# Epoch 00009: val_v_loss did not improve from 0.02203
# Epoch 10/100
# 600000/600000 [==============================] - 35s 58us/step - loss: 0.0199 - p_loss: 1.7924 - v_loss: 0.0199 - p_acc: 0.1422 - val_loss: 0.0225 - val_p_loss: 1.7915 - val_v_loss: 0.0225 - val_p_acc: 0.1485
#
# Epoch 00010: val_v_loss did not improve from 0.02203
# Epoch 11/100
# 600000/600000 [==============================] - 35s 58us/step - loss: 0.0196 - p_loss: 1.7921 - v_loss: 0.0196 - p_acc: 0.1448 - val_loss: 0.0223 - val_p_loss: 1.7918 - val_v_loss: 0.0223 - val_p_acc: 0.1467
#
# Epoch 00011: val_v_loss did not improve from 0.02203
# Epoch 00011: early stopping

# %%
plt.figure(figsize=(16,6))
plt.subplot(1, 2, 1)
plt.plot(history.history['p_acc'])
plt.plot(history.history['val_p_acc'])
plt.legend(['Train', 'Validation'])
plt.title("Action prediction accuracy")
plt.subplot(1, 2, 2)
plt.plot(history.history['v_loss'])
plt.plot(history.history['val_v_loss'])
plt.legend(['Train', 'Validation'])
plt.title("Value MSE")
# Out:
# Text(0.5,1,'Value MSE')

# %%
model.save('conv32_single_value_disc0.9_final.h5')
p_train_pred, v_train_pred = model.predict(x_train, batch_size=2048)
p_test_pred, v_test_pred = model.predict(x_test, batch_size=2048)
act_train_pred = np.argmax(p_train_pred, axis=1)
act_test_pred = np.argmax(p_test_pred, axis=1)
print("Accuracy train:", accuracy_score(p_train, act_train_pred))
print("Accuracy test:", accuracy_score(p_test, act_test_pred))
print("Explained variance train:", explained_variance_score(v_train, v_train_pred))
print("Explained variance test:", explained_variance_score(v_test, v_test_pred))
# Out:
# Accuracy train: 0.14550333333333335
# Accuracy test: 0.14675
# Explained variance train: 0.6547563494894222
# Explained variance test: 0.5891473323786388

# %%
model = load_model('conv32_single_value_disc0.9_best.h5')
p_train_pred, v_train_pred = model.predict(x_train, batch_size=2048)
p_test_pred, v_test_pred = model.predict(x_test, batch_size=2048)
act_train_pred = np.argmax(p_train_pred, axis=1)
act_test_pred = np.argmax(p_test_pred, axis=1)
print("Accuracy train:", accuracy_score(p_train, act_train_pred))
print("Accuracy test:", accuracy_score(p_test, act_test_pred))
print("Explained variance train:", explained_variance_score(v_train, v_train_pred))
print("Explained variance test:", explained_variance_score(v_test, v_test_pred))
# Out:
# Accuracy train: 0.149765
# Accuracy test: 0.1515375
# Explained variance train: 0.6327497719744963
# Explained variance test: 0.5939564122625298
